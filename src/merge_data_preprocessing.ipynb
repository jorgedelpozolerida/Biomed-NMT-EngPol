# %%
import pandas as pd

# %%
data = pd.read_csv("../data/medical_corpus_clean.tsv")
preprocessed_ids = pd.read_csv("../data/preprocessed_ids.tsv")

# %%
filtered_out = data.merge(preprocessed_ids, on="id", how="inner")
filtered_out = filtered_out[["id", "pol", "eng", "split", "src"]]
filtered_out
# Out:
#               id                                                pol  \
# 0       14466574  Urządzenia do odtworzenia i podawania dostarcz...
# 1       23812236                     DOTYCZĄCE DOSTAWY I STOSOWANIA
# 2       11834247  51 jeśli u pacjenta wystąpi ból górnej części ...
# 3       30649221  Wydłużenie czasu protrombinowego (PT) (w przyp...
# 4       25824079                                   Zaburzenia serca
# ...          ...                                                ...
# 884765   3821855  Zmiany obecne po 1 miesiącu podawania produktu...
# 884766  20622458  Delikatnie postukać w strzykawkę, aby usunąć p...
# 884767  36160198  dorosłych pacjentów z nowo rozpoznaną ostrą bi...
# 884768   5426867  Podczas stosowania przewlekłego w badaniu RE–L...
# 884769   3548782                       Jak przechowywać lek Tamiflu
#
#                                                       eng  split  \
# 0       Medical devices for reconstitution and adminis...  train
# ...

# %%
filtered_out.to_csv("medical_corpus_clean_preprocessed.tsv")
